# %%
import pandas as pd

# %%
import requests

# %%
url = 'https://brasilapi.com.br/api/ncm/v1?search'
response = requests.get(url)

# %%
if response.status_code == 200:
    data_json = response.json()
else:
    print('Erro ao acessar a API')

# %%
data = response.json()

# %%
NCM = pd.DataFrame(data_json)
NCM
# Out:
#            codigo                           descricao data_inicio    data_fim  \
# 0              01                      Animais vivos.  2022-04-01  9999-12-31
# 1           01.01  Cavalos, asininos e muares, vivos.  2022-04-01  9999-12-31
# 2          0101.2                          - Cavalos:  2022-04-01  9999-12-31
# 3      0101.21.00        -- Reprodutores de raça pura  2022-04-01  9999-12-31
# 4      0101.29.00                           -- Outros  2022-04-01  9999-12-31
# ...           ...                                 ...         ...         ...
# 15136  9705.31.00             -- Com mais de 100 anos  2022-04-01  9999-12-31
# 15137  9705.39.00                           -- Outras  2022-04-01  9999-12-31
# 15138       97.06  Antiguidades com mais de 100 anos.  2022-04-01  9999-12-31
# 15139  9706.10.00              - Com mais de 250 anos  2022-04-01  9999-12-31
# 15140  9706.90.00                            - Outras  2022-04-01  9999-12-31
#
# ...

# %%
url = 'https://brasilapi.com.br/api/pix/v1/participants'
response = requests.get(url)

# %%
if response.status_code == 200:
    data_json = response.json()
else:
    print('Erro ao acessar a API')

# %%
data = response.json()

# %%
PIX = pd.DataFrame(data_json)
PIX
# Out:
#          ispb                                               nome  \
# 0    00000000                               BANCO DO BRASIL S.A.
# 1    00000208                       BRB - BANCO DE BRASILIA S.A.
# 2    00068987  COOPERATIVA DE CRÉDITO ARACREDI LTDA. - SICOOB...
# 3    00075847  COOPERATIVA DE CRÉDITO UNICRED CENTRO-SUL LTDA...
# 4    00106180  CENTRAL DAS COOPERATIVAS DE CRÉDITO DOS ESTADO...
# ..        ...                                                ...
# 889  95213211  COOPERATIVA DE CRéDITO, POUPANçA E INVESTIMENT...
# 890  95424891  COOPERATIVA DE CRÉDITO, POUPANÇA E INVESTIMENT...
# 891  95594941  COOPERATIVA DE CRÉDITO, POUPANÇA E INVESTIMENT...
# 892  97259253  COOPERATIVA E ECONOMIA E CRÉDITO MÚTUO DOS MÉD...
# 893  97489280  COOPERATIVA DE CRÉDITO, POUPANÇA E INVESTIMENT...
#
#                                          nome_reduzido  \
# 0                                   BCO DO BRASIL S.A.
# 1                           BRB - BCO DE BRASILIA S.A.
# ...

# %%
url = 'https://brasilapi.com.br/api/banks/v1'
response = requests.get(url)

# %%
if response.status_code == 200:
    data_json = response.json()
else:
    print('Erro ao acessar a API')

# %%
data = response.json()

# %%
BANCOS = pd.DataFrame(data_json)
BANCOS
# Out:
#          ispb                        name   code  \
# 0    00000000          BCO DO BRASIL S.A.    1.0
# 1    00000208  BRB - BCO DE BRASILIA S.A.   70.0
# 2    00038121                       Selic    NaN
# 3    00038166                       Bacen    NaN
# 4    00122327       SANTINVEST S.A. - CFI  539.0
# ..        ...                         ...    ...
# 354  92875780            WARREN CVMC LTDA  371.0
# 355  92894922              BANCO ORIGINAL  212.0
# 356  94968518                EFX CC LTDA.  289.0
# 357                                   NaN    NaN
# 358                                   NaN    NaN
#
#                                               fullName
# 0                                 Banco do Brasil S.A.
# 1                         BRB - BANCO DE BRASILIA S.A.
# 2                      Banco Central do Brasil - Selic
# 3                              Banco Central do Brasil
# 4    SANTINVEST S.A. - CREDITO, FINANCIAMENTO E INV...
# ...

# %%
pip install plyer
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.3.1 -> 25.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from plyer import notification
notification.notify(
title='Erro',
message='Houve um erro ao acessar a API',
app_name='NCM',
timeout=10
)

# %%
from plyer import notification
notification.notify(
title='Erro',
message='Houve um erro ao acessar a API',
app_name='pix',
timeout=10
)

# %%
from plyer import notification
notification.notify(
title='Erro',
message='Houve um erro ao acessar a API',
app_name='BANCO',
timeout=10
)
